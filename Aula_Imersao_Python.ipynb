# %% [markdown]
# # Aula 1 - Análise de Dados com Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv')

# %%
df.head(10)
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
# 5     2025.0               EN              FT       Data Engineer   80000
# 6     2025.0               SE              FT      Data Scientist  185000
# 7     2025.0               SE              FT      Data Scientist  148000
# 8     2025.0               MI              FT      Data Scientist  135000
# 9     2025.0               MI              FT      Data Scientist  108000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133349 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           133339 non-null  float64
#  1   experience_level    133349 non-null  object
#  2   employment_type     133349 non-null  object
#  3   job_title           133349 non-null  object
#  4   salary              133349 non-null  int64
#  5   salary_currency     133349 non-null  object
#  6   salary_in_usd       133349 non-null  int64
#  7   employee_residence  133349 non-null  object
#  8   remote_ratio        133349 non-null  int64
#  9   company_location    133349 non-null  object
#  10  company_size        133349 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 11.2+ MB

# %%
df.describe()
# Out:
#            work_year        salary  salary_in_usd   remote_ratio
# count  133339.000000  1.333490e+05  133349.000000  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098      20.905669
# std         0.680627  2.173860e+05   74288.363097      40.590044
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060200e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146206.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
df.shape
# Out:
# (133349, 11)

# %%
lines, columns = df.shape[0], df.shape[1]

# %%
print('lines', lines)
print('columns', columns)
# Out:
# lines 133349
# columns 11

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
# Create a dictionary with the English to Portuguese translation
column_translation = {
    'work_year': 'ano',
    'experience_level': 'senioridade',
    'employment_type': 'contrato',
    'job_title': 'cargo',
    'salary': 'salario',
    'salary_currency': 'moeda',
    'salary_in_usd': 'usd',
    'employee_residence': 'residencia',
    'remote_ratio': 'remoto',
    'company_location': 'empresa',
    'company_size': 'tamanho_empresa'
}

# Rename the columns using the dictionary
df.rename(columns=column_translation, inplace=True)

# Display the updated column names
print(df.columns)
# Out:
# Index(['ano', 'senioridade', 'contrato', 'cargo', 'salario', 'moeda', 'usd',
#        'residencia', 'remoto', 'empresa', 'tamanho_empresa'],
#       dtype='object')

# %%
df['senioridade'].value_counts()
# Out:
# senioridade
# SE    77241
# MI    40465
# EN    12443
# EX     3200
# Name: count, dtype: int64

# %%
df['contrato'].value_counts()
# Out:
# contrato
# FT    132563
# CT       394
# PT       376
# FL        16
# Name: count, dtype: int64

# %%
df['remoto'].value_counts()
# Out:
# remoto
# 0      105312
# 100     27718
# 50        319
# Name: count, dtype: int64

# %%
df['tamanho_empresa'].value_counts()
# Out:
# tamanho_empresa
# M    129561
# L      3574
# S       214
# Name: count, dtype: int64

# %%
# Create a dictionary for translating 'senioridade' categories
senioridade = {
    'SE': 'Senior',
    'MI': 'Pleno',
    'EN': 'Júnior',
    'EX': 'Executivo'
}

# Replace the values in the 'senioridade' column using the translation dictionary
df['senioridade'] = df['senioridade'].replace(senioridade)

# Display the updated value counts for 'senioridade' to confirm the translation
print("Updated value counts for 'senioridade' column:")
display(df['senioridade'].value_counts())
# Out:
# Updated value counts for 'senioridade' column:
# senioridade
# Senior       77241
# Pleno        40465
# Júnior       12443
# Executivo     3200
# Name: count, dtype: int64

# %%
# Create a dictionary for translating 'contrato' categories
contrato = {
    'FT': 'Tempo Integral',
    'CT': 'Contrato',
    'PT': 'Tempo Parcial',
    'FL': 'Freelancer'
}

# Replace the values in the 'contrato' column using the translation dictionary
df['contrato'] = df['contrato'].replace(contrato)

# Display the updated value counts for 'contrato' to confirm the translation
print("Updated value counts for 'contrato' column:")
display(df['contrato'].value_counts())
# Out:
# Updated value counts for 'contrato' column:
# contrato
# Tempo Integral    132563
# Contrato             394
# Tempo Parcial        376
# Freelancer            16
# Name: count, dtype: int64

# %%
# Create a dictionary for translating 'tamanho_empresa' categories
tamanho_empresa_translation = {
    'M': 'Médio',
    'L': 'Grande',
    'S': 'Pequeno'
}

# Replace the values in the 'tamanho_empresa' column using the translation dictionary
df['tamanho_empresa'] = df['tamanho_empresa'].replace(tamanho_empresa_translation)

# Display the updated value counts for 'tamanho_empresa' to confirm the translation
print("Updated value counts for 'tamanho_empresa' column:")
display(df['tamanho_empresa'].value_counts())
# Out:
# Updated value counts for 'tamanho_empresa' column:
# tamanho_empresa
# Médio      129561
# Grande       3574
# Pequeno       214
# Name: count, dtype: int64

# %%
# Create a dictionary for translating 'remoto' categories
remoto_translation = {
    0: 'Presencial',
    100: 'Remoto',
    50: 'Híbrido'
}

# Replace the values in the 'remoto' column using the translation dictionary
df['remoto'] = df['remoto'].replace(remoto_translation)

# Display the updated value counts for 'remoto' to confirm the translation
print("Updated value counts for 'remoto' column:")
display(df['remoto'].value_counts())
# Out:
# Updated value counts for 'remoto' column:
# remoto
# Presencial    105312
# Remoto         27718
# Híbrido          319
# Name: count, dtype: int64

# %%
df.head()
# Out:
#       ano senioridade        contrato               cargo  salario moeda  \
# 0  2025.0      Senior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025.0      Senior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025.0       Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025.0       Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025.0      Júnior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Médio
# 1  136000         US      Remoto      US           Médio
# 2  158800         AU  Presencial      AU           Médio
# 3  139200         AU  Presencial      AU           Médio
# 4   90000         US  Presencial      US           Médio

# %%
df.describe(include='object')
# Out:
#        senioridade        contrato           cargo   moeda residencia  \
# count       133349          133349          133349  133349     133349
# unique           4               4             390      26        102
# top         Senior  Tempo Integral  Data Scientist     USD         US
# freq         77241          132563           17314  126140     119579
#
#             remoto empresa tamanho_empresa
# count       133349  133349          133349
# unique           3      95               3
# top     Presencial      US           Médio
# freq        105312  119641          129561

# %%
df.describe()
# Out:
#                  ano       salario            usd
# count  133339.000000  1.333490e+05  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098
# std         0.680627  2.173860e+05   74288.363097
# min      2020.000000  1.400000e+04   15000.000000
# 25%      2024.000000  1.060200e+05  106000.000000
# 50%      2024.000000  1.470000e+05  146206.000000
# 75%      2025.000000  1.990000e+05  198000.000000
# max      2025.000000  3.040000e+07  800000.000000

# %%
print('Palavra chave aula 1: Pandas')
# Out:
# Palavra chave aula 1: Pandas

# %% [markdown]
# # Aula 2 - Preparação e Limpeza de Dados

# %%
df.isnull()
# Out:
#           ano  senioridade  contrato  cargo  salario  moeda    usd  \
# 0       False        False     False  False    False  False  False
# 1       False        False     False  False    False  False  False
# 2       False        False     False  False    False  False  False
# 3       False        False     False  False    False  False  False
# 4       False        False     False  False    False  False  False
# ...       ...          ...       ...    ...      ...    ...    ...
# 133344  False        False     False  False    False  False  False
# 133345  False        False     False  False    False  False  False
# 133346  False        False     False  False    False  False  False
# 133347  False        False     False  False    False  False  False
# 133348  False        False     False  False    False  False  False
#
#         residencia  remoto  empresa  tamanho_empresa
# 0            False   False    False            False
# 1            False   False    False            False
# ...

# %%
df.head()
# Out:
#       ano senioridade        contrato               cargo  salario moeda  \
# 0  2025.0      Senior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025.0      Senior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025.0       Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025.0       Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025.0      Júnior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Médio
# 1  136000         US      Remoto      US           Médio
# 2  158800         AU  Presencial      AU           Médio
# 3  139200         AU  Presencial      AU           Médio
# 4   90000         US  Presencial      US           Médio

# %%
df.isnull().sum()
# Out:
# ano                10
# senioridade         0
# contrato            0
# cargo               0
# salario             0
# moeda               0
# usd                 0
# residencia          0
# remoto              0
# empresa             0
# tamanho_empresa     0
# dtype: int64

# %%
df['ano'].unique()
# Out:
# array([2025.,   nan, 2024., 2022., 2023., 2020., 2021.])

# %%
df[df.isnull().any(axis=1)]
# Out:
#         ano senioridade        contrato                      cargo  salario  \
# 5588    NaN      Senior  Tempo Integral            Product Manager   184500
# 59692   NaN       Pleno  Tempo Integral                   Engineer   110000
# 59710   NaN      Júnior  Tempo Integral             Data Scientist   208800
# 59759   NaN      Senior  Tempo Integral          Software Engineer   135000
# 59789   NaN      Senior  Tempo Integral                   Engineer   112000
# 131000  NaN      Senior  Tempo Integral  Machine Learning Engineer   163800
# 131006  NaN      Senior  Tempo Integral     Data Analytics Manager   204500
# 133054  NaN      Júnior  Tempo Integral             Data Scientist    40000
# 133281  NaN       Pleno  Tempo Integral  Machine Learning Engineer   180000
# 133317  NaN       Pleno  Tempo Integral             Data Scientist   130000
#
#        moeda     usd residencia      remoto empresa tamanho_empresa
# ...

# %%
import numpy as np

# criação de um dataframe de teste para usar de exemplo
df_salarios = pd.DataFrame({
  'nome': ['Ana','Bruno', 'Carlos', 'Daniele', 'Val'],
  'salario': [4000, np.nan, 5000, np.nan, 100000]
})

# calcula  a média salarial e substitui os nulos pela média e arredonda os valores
df_salarios['salario_media'] = df_salarios['salario'].fillna(df_salarios['salario'].mean().round(2))

# calcula a mediana e substitui os nulos pela mediana
df_salarios['salario_mediana'] = df_salarios['salario'].fillna(df_salarios['salario'].median())

# printa o df_salarios
df_salarios
# Out:
#       nome   salario  salario_media  salario_mediana
# 0      Ana    4000.0        4000.00           4000.0
# 1    Bruno       NaN       36333.33           5000.0
# 2   Carlos    5000.0        5000.00           5000.0
# 3  Daniele       NaN       36333.33           5000.0
# 4      Val  100000.0      100000.00         100000.0

# %%
df_temperaturas = pd.DataFrame({
    'Dia': ['Domingo', 'Segunda', 'Terça', 'Quarta', 'Quinta', 'Sexta', 'Sabado'],
    'Temperatura': [np.nan, 30, np.nan, np.nan, 28, 27, 26]
})

# fill all nan values with some of this two strategies

# ffill -> forward fill
# df_temperaturas['Preenchido_ffill'] = df_temperaturas['Temperatura'].ffill()

# bfill -> back fill
df_temperaturas['Preenchido_bfill'] = df_temperaturas['Temperatura'].bfill()

df_temperaturas
# Out:
#        Dia  Temperatura  Preenchido_bfill
# 0  Domingo          NaN              30.0
# 1  Segunda         30.0              30.0
# 2    Terça          NaN              28.0
# 3   Quarta          NaN              28.0
# 4   Quinta         28.0              28.0
# 5    Sexta         27.0              27.0
# 6   Sabado         26.0              26.0

# %%
df_cities = pd.DataFrame({
    'Name': ['Ana','Bruno', 'Carlos', 'Daniele', 'Val'],
    'City': ['São Paulo', np.nan, 'Curitiba', np.nan, 'Belém']
})

df_cities['Filled City'] = df_cities['City'].fillna('Not Informed')
display(df_cities)
# Out:
#       Name       City   Filled City
# 0      Ana  São Paulo     São Paulo
# 1    Bruno        NaN  Not Informed
# 2   Carlos   Curitiba      Curitiba
# 3  Daniele        NaN  Not Informed
# 4      Val      Belém         Belém

# %%
df_clean = df.dropna()

# %%
df_clean.isnull().sum()
# Out:
# ano                0
# senioridade        0
# contrato           0
# cargo              0
# salario            0
# moeda              0
# usd                0
# residencia         0
# remoto             0
# empresa            0
# tamanho_empresa    0
# dtype: int64

# %%
df_clean.head()
# Out:
#       ano senioridade        contrato               cargo  salario moeda  \
# 0  2025.0      Senior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025.0      Senior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025.0       Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025.0       Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025.0      Júnior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Médio
# 1  136000         US      Remoto      US           Médio
# 2  158800         AU  Presencial      AU           Médio
# 3  139200         AU  Presencial      AU           Médio
# 4   90000         US  Presencial      US           Médio

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133339 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ano              133339 non-null  float64
#  1   senioridade      133339 non-null  object
#  2   contrato         133339 non-null  object
#  3   cargo            133339 non-null  object
#  4   salario          133339 non-null  int64
#  5   moeda            133339 non-null  object
#  6   usd              133339 non-null  int64
#  7   residencia       133339 non-null  object
#  8   remoto           133339 non-null  object
#  9   empresa          133339 non-null  object
#  10  tamanho_empresa  133339 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 12.2+ MB

# %%
df_clean = df_clean.assign(ano = df_clean['ano'].astype('int64'))
display(df_clean)
# Out:
#          ano senioridade        contrato                     cargo  salario  \
# 0       2025      Senior  Tempo Integral        Solutions Engineer   214000
# 1       2025      Senior  Tempo Integral        Solutions Engineer   136000
# 2       2025       Pleno  Tempo Integral             Data Engineer   158800
# 3       2025       Pleno  Tempo Integral             Data Engineer   139200
# 4       2025      Júnior  Tempo Integral             Data Engineer    90000
# ...      ...         ...             ...                       ...      ...
# 133344  2020      Senior  Tempo Integral            Data Scientist   412000
# 133345  2021       Pleno  Tempo Integral  Principal Data Scientist   151000
# 133346  2020      Júnior  Tempo Integral            Data Scientist   105000
# 133347  2020      Júnior        Contrato     Business Data Analyst   100000
# 133348  2021      Senior  Tempo Integral            Data Scientist  7000000
#
# ...

# %%
print('Palavra chave aula 2: Print')
# Out:
# Palavra chave aula 2: Print

# %% [markdown]
# # Aula 3 - Visualização de Dados

# %%
df_clean.head()
# Out:
#     ano senioridade        contrato               cargo  salario moeda  \
# 0  2025      Senior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025      Senior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025       Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025       Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025      Júnior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Médio
# 1  136000         US      Remoto      US           Médio
# 2  158800         AU  Presencial      AU           Médio
# 3  139200         AU  Presencial      AU           Médio
# 4   90000         US  Presencial      US           Médio

# %%
df_clean['senioridade'].value_counts().plot(kind='bar', title='Dist. Senioridade')
# Out:
# <Axes: title={'center': 'Dist. Senioridade'}, xlabel='senioridade'>

# %%
import seaborn as sns

# %%
sns.barplot(data=df_clean, x='senioridade', y='usd')
# Out:
# <Axes: xlabel='senioridade', ylabel='usd'>

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=df_clean, x='senioridade', y='usd')
plt.title('Salário Médio por Senioridade')
plt.xlabel('Senioridade')
plt.ylabel('Salário Médio Anual (USD)')
plt.show()

# %%
df_clean.groupby('senioridade')['usd'].mean().sort_values(ascending=False)
# Out:
# senioridade
# Executivo    202027.667813
# Senior       172850.838301
# Pleno        143044.845979
# Júnior        99034.963267
# Name: usd, dtype: float64

# %%
ordem = df_clean.groupby('senioridade')['usd'].mean().sort_values(ascending=False).index
ordem
# Out:
# Index(['Executivo', 'Senior', 'Pleno', 'Júnior'], dtype='object', name='senioridade')

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=df_clean, x='senioridade', y='usd', order=ordem)
plt.title('Salário Médio por Senioridade')
plt.xlabel('Senioridade')
plt.ylabel('Salário Médio Anual (USD)')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(data=df_clean, x='usd', bins=50, kde=True)
plt.title('Distribuição dos Salários Anuais')
plt.xlabel('Salário em USD')
plt.ylabel('Frequência')
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(data=df_clean, x='usd')
plt.title('Boxplot Salários')
plt.xlabel('Salário em USD')
plt.show()

# %%
ordem_senioridade = ['Júnior', 'Pleno', 'Senior', 'Executivo']

plt.figure(figsize=(8, 5))
sns.boxplot(x='senioridade', y='usd', data=df_clean, order=ordem_senioridade)
plt.title('Boxplot da Distribuição por Senioridade')
plt.xlabel('Salário em USD')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='senioridade', y='usd', data=df_clean, order=ordem_senioridade, palette='Set2', hue='senioridade')
plt.title('Boxplot da Distribuição por Senioridade')
plt.xlabel('Salário em USD')
plt.show()

# %%
import plotly.express as px

# %%
import plotly.express as px

# Calculate the average salary by seniority
average_salary_by_seniority = df_clean.groupby('senioridade')['usd'].mean().sort_values(ascending=False).reset_index()

# Define the desired order for seniority levels
# ordem_senioridade = ['Júnior', 'Pleno', 'Senior', 'Executivo']

# Sort the dataframe by the desired order
# average_salary_by_seniority['senioridade'] = pd.Categorical(average_salary_by_seniority['senioridade'], categories=ordem_senioridade, ordered=True)
# average_salary_by_seniority = average_salary_by_seniority.sort_values('senioridade')

# Create the bar chart using Plotly Express
fig = px.bar(average_salary_by_seniority,
             x='senioridade',
             y='usd',
             title='Salário Médio por Senioridade',
             labels={'senioridade': 'Senioridade', 'usd': 'Salário Médio Anual (USD)'})

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_contagem = df_clean['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']

fig = px.pie(remoto_contagem,
             names='tipo_trabalho',
             values='quantidade',
             title='Proporção dos tipos de trabalho')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(remoto_contagem,
             names='tipo_trabalho',
             values='quantidade',
             title='Proporção dos tipos de trabalho',
             hole=0.5)

fig.update_traces(textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
print('Palavra chave aula 3: Matplotlib')

# %% [markdown]
# # Aula 4 - Construindo um Dashboard com Streamlit
#
# > Aprender a usar a biblioteca Streamlit para a criação de um dashboard interativo simples, que permite visualizar dados filtrados e gerar gráficos de forma prática.
#
# https://dashboard-salarios-dados.streamlit.app/
#
# 1. Criar o ambiente virtual:
#
# ```python3 -m venv .venv```
# 2. Ativar o ambiente virtual em Windows:
#
# ```.venv\Scripts\Activate```
# 3. Ativar o ambiente virtual em MAC/LINUX:
#
# ```source .venv/bin/activate```
# 4. Criar um arquivo chamado requirements.txt e adicionar os pacotes necessários
#
# ```
# pandas==2.2.3
# streamlit==1.44.1
# plotly==5.24.1
# ```
# 5. Instalar as bibliotecas necessárias
#
# ```pip install -r requirements.txt```
# 6. Criar a Interface do Dashboard com Streamlit
# 7. Realizar o deploy do Dashboard no Streamlit Cloud:
#
# ```https://streamlit.io/cloud```

# %%
import streamlit as st
import pandas as pd
import plotly.express as px

# --- Configuração da Página ---
# Define o título da página, o ícone e o layout para ocupar a largura inteira.
st.set_page_config(
    page_title="Dashboard de Salários na Área de Dados",
    page_icon="📊",
    layout="wide",
)

# --- Carregamento dos dados ---
df = pd.read_csv("https://raw.githubusercontent.com/vqrca/dashboard_salarios_dados/refs/heads/main/dados-imersao-final.csv")

# --- Barra Lateral (Filtros) ---
st.sidebar.header("🔍 Filtros")

# Filtro de Ano
anos_disponiveis = sorted(df['ano'].unique())
anos_selecionados = st.sidebar.multiselect("Ano", anos_disponiveis, default=anos_disponiveis)

# Filtro de Senioridade
senioridades_disponiveis = sorted(df['senioridade'].unique())
senioridades_selecionadas = st.sidebar.multiselect("Senioridade", senioridades_disponiveis, default=senioridades_disponiveis)

# Filtro por Tipo de Contrato
contratos_disponiveis = sorted(df['contrato'].unique())
contratos_selecionados = st.sidebar.multiselect("Tipo de Contrato", contratos_disponiveis, default=contratos_disponiveis)

# Filtro por Tamanho da Empresa
tamanhos_disponiveis = sorted(df['tamanho_empresa'].unique())
tamanhos_selecionados = st.sidebar.multiselect("Tamanho da Empresa", tamanhos_disponiveis, default=tamanhos_disponiveis)

# --- Filtragem do DataFrame ---
# O dataframe principal é filtrado com base nas seleções feitas na barra lateral.
df_filtrado = df[
    (df['ano'].isin(anos_selecionados)) &
    (df['senioridade'].isin(senioridades_selecionadas)) &
    (df['contrato'].isin(contratos_selecionados)) &
    (df['tamanho_empresa'].isin(tamanhos_selecionados))
]

# --- Conteúdo Principal ---
st.title("🎲 Dashboard de Análise de Salários na Área de Dados")
st.markdown("Explore os dados salariais na área de dados nos últimos anos. Utilize os filtros à esquerda para refinar sua análise.")

# --- Métricas Principais (KPIs) ---
st.subheader("Métricas gerais (Salário anual em USD)")

if not df_filtrado.empty:
    salario_medio = df_filtrado['usd'].mean()
    salario_maximo = df_filtrado['usd'].max()
    total_registros = df_filtrado.shape[0]
    cargo_mais_frequente = df_filtrado["cargo"].mode()[0]
else:
    salario_medio, salario_mediano, salario_maximo, total_registros, cargo_mais_comum = 0, 0, 0, ""

col1, col2, col3, col4 = st.columns(4)
col1.metric("Salário médio", f"${salario_medio:,.0f}")
col2.metric("Salário máximo", f"${salario_maximo:,.0f}")
col3.metric("Total de registros", f"{total_registros:,}")
col4.metric("Cargo mais frequente", cargo_mais_frequente)

st.markdown("---")

# --- Análises Visuais com Plotly ---
st.subheader("Gráficos")

col_graf1, col_graf2 = st.columns(2)

with col_graf1:
    if not df_filtrado.empty:
        top_cargos = df_filtrado.groupby('cargo')['usd'].mean().nlargest(10).sort_values(ascending=True).reset_index()
        grafico_cargos = px.bar(
            top_cargos,
            x='usd',
            y='cargo',
            orientation='h',
            title="Top 10 cargos por salário médio",
            labels={'usd': 'Média salarial anual (USD)', 'cargo': ''}
        )
        grafico_cargos.update_layout(title_x=0.1, yaxis={'categoryorder':'total ascending'})
        st.plotly_chart(grafico_cargos, use_container_width=True)
    else:
        st.warning("Nenhum dado para exibir no gráfico de cargos.")

with col_graf2:
    if not df_filtrado.empty:
        grafico_hist = px.histogram(
            df_filtrado,
            x='usd',
            nbins=30,
            title="Distribuição de salários anuais",
            labels={'usd': 'Faixa salarial (USD)', 'count': ''}
        )
        grafico_hist.update_layout(title_x=0.1)
        st.plotly_chart(grafico_hist, use_container_width=True)
    else:
        st.warning("Nenhum dado para exibir no gráfico de distribuição.")

col_graf3, col_graf4 = st.columns(2)

with col_graf3:
    if not df_filtrado.empty:
        remoto_contagem = df_filtrado['remoto'].value_counts().reset_index()
        remoto_contagem.columns = ['tipo_trabalho', 'quantidade']
        grafico_remoto = px.pie(
            remoto_contagem,
            names='tipo_trabalho',
            values='quantidade',
            title='Proporção dos tipos de trabalho',
            hole=0.5
        )
        grafico_remoto.update_traces(textinfo='percent+label')
        grafico_remoto.update_layout(title_x=0.1)
        st.plotly_chart(grafico_remoto, use_container_width=True)
    else:
        st.warning("Nenhum dado para exibir no gráfico dos tipos de trabalho.")

with col_graf4:
    if not df_filtrado.empty:
        df_ds = df_filtrado[df_filtrado['cargo'] == 'Data Scientist']
        media_ds_pais = df_ds.groupby('residencia_iso3')['usd'].mean().reset_index()
        grafico_paises = px.choropleth(media_ds_pais,
            locations='residencia_iso3',
            color='usd',
            color_continuous_scale='rdylgn',
            title='Salário médio de Cientista de Dados por país',
            labels={'usd': 'Salário médio (USD)', 'residencia_iso3': 'País'})
        grafico_paises.update_layout(title_x=0.1)
        st.plotly_chart(grafico_paises, use_container_width=True)
    else:
        st.warning("Nenhum dado para exibir no gráfico de países.")

# --- Tabela de Dados Detalhados ---
st.subheader("Dados Detalhados")
st.dataframe(df_filtrado)

# %% [markdown]
# ### DESAFIO AULA 3

# %%
# pip install pycountry

# %%
# import pycountry

# # Função para converter ISO-2 para ISO-3
# def iso2_to_iso3(code):
#     try:
#         return pycountry.countries.get(alpha_2=code).alpha_3
#     except:
#         return None

# # Criar nova coluna com código ISO-3
# df_limpo['residencia_iso3'] = df_limpo['residencia'].apply(iso2_to_iso3)

# # Calcular média salarial por país (ISO-3)
# df_ds = df_limpo[df_limpo['cargo'] == 'Data Scientist']
# media_ds_pais = df_ds.groupby('residencia_iso3')['usd'].mean().reset_index()

# # Gerar o mapa
# fig = px.choropleth(media_ds_pais,
#                     locations='residencia_iso3',
#                     color='usd',
#                     color_continuous_scale='rdylgn',
#                     title='Salário médio de Cientista de Dados por país',
#                     labels={'usd': 'Salário médio (USD)', 'residencia_iso3': 'País'})

# fig.show()

# %%
df_clean.head()

# %%
# df_clean.to_csv('dados-imersao-final.csv', index=False)

# %%
print('Palavra chave aula 4: ')
